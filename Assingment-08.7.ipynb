# %%
# Assingment No. 08
# Assingment No.07

# %%
# Task-01

# %%
# Task-02

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("product_sales.csv")
df
# Out:
#     Product_Price  Monthly_Sales  Customer_Rating
# 0           60.30            249              3.8
# 1           55.00            334              3.8
# 2           64.49            200              4.5
# 3          176.14             76              4.7
# 4           11.43            524              3.5
# ..            ...            ...              ...
# 85          57.19            151              4.4
# 86          22.29            563              4.0
# 87         129.74             36              4.4
# 88         114.31             70              5.0
# 89          22.46            782              3.7
#
# [90 rows x 3 columns]

# %%
# Task-03

# %%
X = df[["Product_Price", "Monthly_Sales", "Customer_Rating"]]
kmeans = KMeans(n_clusters=3, init="k-means++", random_state=42, n_init=10)
kmeans.fit(X)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=3, n_init=10, random_state=42)

# %%
# Task-04

# %%
df["Cluster"] = kmeans.predict(X)
print(df["Cluster"].value_counts().sort_index())
# Out:
# Cluster
# 0    36
# 1    28
# 2    26
# Name: count, dtype: int64

# %%
# Task-05

# %%
centers = pd.DataFrame(
    kmeans.cluster_centers_,
    columns=["Product_Price", "Monthly_Sales", "Customer_Rating"]
)
centers.index.name = "Cluster"
centers
# Out:
#          Product_Price  Monthly_Sales  Customer_Rating
# Cluster
# 0           124.653611      77.916667         4.600000
# 1            16.027857     688.321429         3.492857
# 2            48.743462     317.192308         4.119231

# %%
# Task-06

# %%
plt.scatter(
    kmeans.cluster_centers_[:, 0],   
    kmeans.cluster_centers_[:, 1],   
    s=300, c="black", marker="X", label="Centroids"
)

plt.xlabel("Product Price")
plt.ylabel("Monthly Sales")
plt.title("Product Sales C")
# Out:
# Text(0.5, 1.0, 'Product Sales C')
