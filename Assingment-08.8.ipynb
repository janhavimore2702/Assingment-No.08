# %%
# Assingmeny-08
# Assingmnt No. 08

# %%
# Task 01

# %%
# Task-02

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering, KMeans
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.metrics import adjusted_rand_score

# %%
df = pd.read_csv("house_data.csv")
df
# Out:
#     Area_sqft  Bedrooms    Price
# 0         513         2  1004559
# 1         514         1  1504362
# 2         825         1   856567
# 3        1499         3  2896399
# 4        3324         4  8317324
# ..        ...       ...      ...
# 95        716         1  1077795
# 96       1815         3  3569841
# 97       2608         4  5666989
# 98       1363         3  4130996
# 99        680         2  1168294
#
# [100 rows x 3 columns]

# %%
# Task-03

# %%
X = df[["Area_sqft", "Bedrooms", "Price"]]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-1.1979071 , -0.75599316, -1.07780734],
#        [-1.19700528, -1.4077114 , -0.92473332],
#        [-0.9165389 , -1.4077114 , -1.12313266],
#        [-0.30871143, -0.10427492, -0.49839594],
#        [ 1.33711222,  0.54744332,  1.1618638 ],
#        [ 1.01155478,  1.8508798 ,  1.84005208],
#        [-0.15630365, -0.10427492, -0.47827408],
#        [ 1.34071951,  0.54744332,  1.22128667],
#        [ 1.56346934,  1.8508798 ,  0.79327859],
#        [-0.53416672, -0.10427492, -0.49634669],
#        [-0.35921341, -0.10427492, -0.41308938],
#        [-0.95261174, -0.75599316, -0.8158992 ],
#        [-1.07706307, -0.75599316, -0.82126901],
#        [ 0.77437581,  0.54744332,  1.45022591],
#        [-0.99499734, -1.4077114 , -0.77355724],
#        [-0.32223874, -0.10427492, -0.08650739],
#        [ 1.8385248 ,  1.19916156,  0.49719392],
#        [ 0.91776537,  1.8508798 ,  2.03342678],
#        [ 1.03951123,  1.19916156,  1.74524262],
#        [-1.01213194, -0.75599316, -1.04085388],
#        [-0.82184767, -1.4077114 , -0.96580855],
#        [-1.13658326, -0.75599316, -0.86121196],
#        [-0.96523724, -0.75599316, -1.11387539],
#        [-0.49448659, -0.10427492, -0.13146059],
#        [ 1.4768945 ,  1.19916156,  1.93424318],
#        [ 0.71395379,  0.54744332,  2.28961811],
#        [ 0.90333624,  0.54744332,  0.57301381],
#        [-1.08788492, -1.4077114 , -0.7736188 ],
#        [-0.11031077, -0.10427492, -0.14729867],
#        [-1.10952863, -1.4077114 , -1.09336579],
#        [ 1.62930228,  1.19916156,  0.7556103 ],
#        [ 1.85746304,  0.54744332,  0.42100835],
#        [-0.97966638, -1.4077114 , -1.05770601],
#        [ 1.40384699,  0.54744332,  1.88866489],
#        [-0.4611192 , -0.10427492, -0.19711756],
#        [-0.85792052, -1.4077114 , -0.83743173],
#        [-0.85611688, -0.75599316, -1.01664364],
#        [ 1.44082166,  0.54744332,  1.34160342],
#        [ 0.89702349,  0.54744332,  2.01426906],
#        [ 0.13047549, -0.10427492, -0.20124943],
#        [-0.03365597, -0.10427492, -0.36984883],
#        [-1.13838691, -1.4077114 , -0.82375591],
#        [ 0.97728557,  1.8508798 ,  0.72052507],
#        [-0.88768062, -0.75599316, -1.0795396 ],
#        [-1.20963078, -0.75599316, -0.83865252],
#        [-0.39528626, -0.10427492, -0.5012865 ],
#        [-0.21041292, -0.10427492, -0.11176629],
#        [-0.39979536, -0.10427492, -0.25675604],
#        [-0.88858244, -1.4077114 , -1.066529  ],
#        [ 1.2252864 ,  1.8508798 ,  0.67493605],
#        [-0.22844934, -0.10427492, -0.25102943],
#        [-0.18876921, -0.10427492, -0.17500006],
#        [-0.46562831, -0.10427492, -0.08963593],
#        [-1.15912879, -1.4077114 , -0.90442617],
#        [-0.94720082, -0.75599316, -0.86457265],
#        [ 0.86906703,  0.54744332,  1.29280501],
#        [ 1.35965775,  1.19916156,  1.82217732],
#        [ 1.5959349 ,  1.8508798 ,  2.17497775],
#        [-1.11764502, -0.75599316, -0.96237926],
#        [ 1.89984864,  1.8508798 ,  0.95672594],
#        [-1.1212523 , -0.75599316, -1.03406727],
#        [-1.1338778 , -1.4077114 , -1.04080426],
#        [-0.91022615, -1.4077114 , -1.0004062 ],
#        [ 0.04660612, -0.10427492, -0.31966793],
#        [-0.28887136, -0.10427492, -0.19197072],
#        [-0.35470431, -0.10427492, -0.59928483],
#        [ 1.36777414,  1.19916156,  1.18693037],
#        [-0.17343825, -0.10427492, -0.0241373 ],
#        [-0.99229188, -0.75599316, -0.86402443],
#        [ 1.51657464,  1.19916156,  0.56932511],
#        [-0.16261639, -0.10427492, -0.30973808],
#        [-0.51252301, -0.10427492, -0.07167235],
#        [-0.85611688, -1.4077114 , -0.84855847],
#        [-1.10592134, -1.4077114 , -0.9285234 ],
#        [-0.04267418, -0.10427492, -0.54249251],
#        [-0.537774  , -0.10427492, -0.25765004],
#        [-0.32764967, -0.10427492, -0.13866587],
#        [-0.79479304, -0.75599316, -1.05170284],
#        [-0.95712085, -0.75599316, -1.05574466],
#        [ 1.85295393,  0.54744332,  1.77589185],
#        [ 1.16486438,  1.19916156,  0.49495694],
#        [-1.18437979, -0.75599316, -0.92266417],
#        [-0.03996871, -0.10427492, -0.53270508],
#        [ 1.58060394,  1.8508798 ,  1.88194811],
#        [ 1.2126609 ,  1.19916156,  1.1853053 ],
#        [ 1.80245195,  1.8508798 ,  0.86644068],
#        [ 1.51206553,  1.8508798 ,  2.19334897],
#        [ 1.0295912 ,  1.8508798 ,  1.14271558],
#        [-0.2140202 , -0.10427492, -0.59655108],
#        [-0.23927119, -0.10427492, -0.20347846],
#        [-1.01483741, -0.75599316, -0.93715864],
#        [ 0.01053327, -0.10427492, -0.12083858],
#        [-0.36552616, -0.10427492, -0.41533709],
#        [ 1.49312729,  1.8508798 ,  0.51905661],
#        [-0.45751192, -0.10427492, -0.02368341],
#        [-1.01483741, -1.4077114 , -1.05537745],
#        [-0.02373593, -0.10427492, -0.29214172],
#        [ 0.69140826,  0.54744332,  0.35014911],
#        [-0.43135911, -0.10427492, -0.1202775 ],
#        [-1.04730297, -0.75599316, -1.02766044]])

# %%
# Task-04

# %%
hc_model = AgglomerativeClustering(n_clusters=3, linkage="ward")
hc_model
# Out:
# AgglomerativeClustering(n_clusters=3)

# %%
# Task-05

# %%
df["HC_Cluster"] = hc_model.fit_predict(X_scaled)
print(df["HC_Cluster"].value_counts().sort_index())
# Out:
# HC_Cluster
# 0    33
# 1    34
# 2    33
# Name: count, dtype: int64

# %%
# Task-06
